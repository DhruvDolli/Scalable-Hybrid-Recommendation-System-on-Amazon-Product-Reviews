# %%
pip install pandas pyarrow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the combined Parquet file
df = pd.read_parquet(r"path\combined.parquet")

# Preview the data
df.head()
# Out:
#                      id                                               name  \
# 0  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 1  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 2  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 3  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
# 4  AVqkIhwDv8e3D1O-lebb  All-New Fire HD 8 Tablet, 8 HD Display, Wi-Fi,...
#
#         asins   brand                                         categories  \
# 0  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 1  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 2  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 3  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
# 4  B01AHB9CN2  Amazon  Electronics,iPad & Tablets,All Tablets,Fire Ta...
#
#                                                 keys manufacturer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67863 entries, 0 to 67862
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    67863 non-null  object
#  1   name                  61104 non-null  object
#  2   asins                 67861 non-null  object
#  3   brand                 67863 non-null  object
#  4   categories            67863 non-null  object
#  5   keys                  67863 non-null  object
#  6   manufacturer          67863 non-null  object
#  7   reviews.date          67712 non-null  datetime64[ns, UTC]
#  8   reviews.dateAdded     25083 non-null  object
#  9   reviews.dateSeen      67863 non-null  object
#  10  reviews.didPurchase   10 non-null     object
#  11  reviews.doRecommend   55057 non-null  object
#  12  reviews.id            71 non-null     float64
#  13  reviews.numHelpful    55151 non-null  float64
# ...

# %%
df.describe()
# Out:
#          reviews.id  reviews.numHelpful  reviews.rating  reviews.userCity  \
# count  7.100000e+01        55151.000000    67863.000000               0.0
# mean   1.837463e+08            0.572320        4.556135               NaN
# std    2.371858e+07           11.596709        0.824940               NaN
# min    1.082112e+08            0.000000        1.000000               NaN
# 25%    1.843760e+08            0.000000        4.000000               NaN
# 50%    1.880757e+08            0.000000        5.000000               NaN
# 75%    1.987126e+08            0.000000        5.000000               NaN
# max    2.085304e+08          814.000000        5.000000               NaN
#
#        reviews.userProvince
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
df.columns
# Out:
# Index(['id', 'name', 'asins', 'brand', 'categories', 'keys', 'manufacturer',
#        'reviews.date', 'reviews.dateAdded', 'reviews.dateSeen',
#        'reviews.didPurchase', 'reviews.doRecommend', 'reviews.id',
#        'reviews.numHelpful', 'reviews.rating', 'reviews.sourceURLs',
#        'reviews.text', 'reviews.title', 'reviews.userCity',
#        'reviews.userProvince', 'reviews.username', 'dateAdded', 'dateUpdated',
#        'primaryCategories', 'imageURLs', 'manufacturerNumber', 'sourceURLs'],
#       dtype='object')

# %%
import plotly.express as px

fig = px.histogram(df, x="reviews.rating", nbins=5, title="Rating Distribution")
fig.show()
